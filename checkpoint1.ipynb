# %% [markdown]
# <a href="https://colab.research.google.com/github/nounou-mimi/SIC-checkpoints/blob/main/checkpoint1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to python world! Let's start coding")
# Out:
# Welcome to python world! Let's start coding
